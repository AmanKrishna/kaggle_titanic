# %%
import sklearn as sk
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Import Files

# %%
train = pd.read_csv("../data/train.csv")
test = pd.read_csv("../data/test.csv")
gender = pd.read_csv("../data/gender_submission.csv")
display(train.head())
display(test)
display(gender)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# ...

# %% [markdown]
# ### Create new column

# %%
# Create New Columns
train["Relatives"] = train["SibSp"] + train["Parch"]
train["Fare_Bins"] = pd.qcut(train["Fare"], 10)
train["Age_Bins"] = pd.qcut(train["Age"], 8)

# %% [markdown]
# ### Overview

# %%
print(train.info())
display(train.describe())
display(pd.DataFrame(train.isnull().sum()))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
# None
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# ...

# %% [markdown]
# ### Correlation

# %%
# Set plot size
fig, ax = plt.subplots(figsize=(20, 12))

# Drop PassengerId
df_train = train.drop(["PassengerId"], axis = 1)
# Convert Sex to numnerical
df_train["Sex"] = df_train["Sex"].apply(lambda x: 1 if x == "female" else 0)

dataplot = sns.heatmap(df_train.corr(), annot=True)
# displaying heatmap
plt.show()

# %% [markdown]
# ### Count Unique

# %%
columns = train.columns
for i in columns:
    print("Unique values for "+i+":",len(train.groupby(i)['PassengerId'].nunique()))
    if i not in ["PassengerId", "Age", "Ticket", "Fare", "Name"]:
        display(train.groupby(i)['PassengerId'].nunique())
    print("\n")
# Out:
# Unique values for PassengerId: 891
#
#
# Unique values for Survived: 2
# Survived
# 0    549
# 1    342
# Name: PassengerId, dtype: int64
# Unique values for Pclass: 3
# Pclass
# 1    216
# 2    184
# 3    491
# Name: PassengerId, dtype: int64
# Unique values for Name: 891
#
#
# Unique values for Sex: 2
# Sex
# female    314
# male      577
# Name: PassengerId, dtype: int64
# Unique values for Age: 88
#
#
# Unique values for SibSp: 7
# SibSp
# 0    608
# 1    209
# 2     28
# 3     16
# 4     18
# 5      5
# 8      7
# Name: PassengerId, dtype: int64
# Unique values for Parch: 7
# Parch
# 0    678
# 1    118
# 2     80
# 3      5
# 4      4
# 5      5
# 6      1
# Name: PassengerId, dtype: int64
# Unique values for Ticket: 681
#
#
# Unique values for Fare: 248
#
#
# Unique values for Cabin: 147
# Cabin
# A10    1
# A14    1
# A16    1
# A19    1
# A20    1
#       ..
# F33    3
# F38    1
# F4     2
# G6     4
# T      1
# Name: PassengerId, Length: 147, dtype: int64
# ...

# %% [markdown]
# ### Insights and Graphs

# %%
numerical_cols = ["Fare", "Age", "SibSp", "Parch"]
categorical_cols = ['Pclass', 'Sex', 'Embarked']

# %% [markdown]
# #### Function to show value on top of Barplot

# %% [markdown]
# ### Show Values above Barplots

# %%
def show_values(axs, orient="v", space=.01):
    def _single(ax):
        if orient == "v":
            for p in ax.patches:
                _x = p.get_x() + p.get_width() / 2
                _y = p.get_y() + p.get_height() + (p.get_height()*0.01)
                value = '{:.2f}'.format(p.get_height())
                ax.text(_x, _y, value, ha="center") 
        elif orient == "h":
            for p in ax.patches:
                _x = p.get_x() + p.get_width() + float(space)
                _y = p.get_y() + p.get_height() - (p.get_height()*0.5)
                value = '{:.2f}'.format(p.get_width())
                ax.text(_x, _y, value, ha="left")

    if isinstance(axs, np.ndarray):
        for idx, ax in np.ndenumerate(axs):
            _single(ax)
    else:
        _single(axs)

# %% [markdown]
# ### Count Plot Function

# %%
def count_plot_function_categorical(df, feature_1, feature_2, title, rotation = False):
    # Set plot style
    sns.set(font_scale = 1.5)
    sns.set_palette("deep")
    sns.set_style("darkgrid")
    fig, ax = plt.subplots(figsize=(18,12))
    # Plot
    g = sns.countplot(
        x = feature_1,
        hue = feature_2,
        data = df,
        ax = ax
    ).set_title(title)
    show_values(ax)
    
    if rotation:
        plt.xticks(rotation=30)

# %% [markdown]
# ### Bar plot function

# %%
def bar_plot_function_categorical(df, feature_1, feature_2, title, feature_3 = None, rotation = False):
    # Set plot style
    sns.set(font_scale = 1.5)
    sns.set_palette("deep")
    sns.set_style("darkgrid")
    fig, ax = plt.subplots(figsize=(18,12))
    # Plot
    g = sns.barplot(
        x = feature_1,
        y= feature_2,
        hue = feature_3,
        data = df,
        ci = None,
        ax = ax
    ).set_title(title)
    show_values(ax)
    
    if rotation:
        plt.xticks(rotation=30)

# %% [markdown]
# ### Distribution Plot

# %%
def dist_plot(df, feature_1, title):
    # Set plot style
    sns.set(font_scale = 1.5)
    sns.set_palette("deep")
    sns.set_style("darkgrid")
    fig, ax = plt.subplots(figsize=(18,12))
    
    f = sns.distplot(
        df[feature_1],
        bins=40, 
        ax=ax).set_title(title)

# %% [markdown]
# ### KDE Plot

# %%
def dist_plot_survive(df, feature_1, title):
    # Set plot style
    sns.set(font_scale = 1.5)
    sns.set_palette("deep")
    sns.set_style("darkgrid")
    fig, ax = plt.subplots(figsize=(18,12))
    
    ax.set_title(title)
    g = sns.kdeplot(
        x=df[feature_1],
        shade= True,
        hue=df["Survived"],
        ax=ax,
    ).set_xlabel(feature_1)

# %% [markdown]
# ### Swarm Plot

# %%
def swarm_plot(df, feature_1, feature_2, title):
    # Set plot style
    sns.set(font_scale = 1.5)
    sns.set_palette("deep")
    sns.set_style("darkgrid")
    fig, ax = plt.subplots(figsize=(18,12))
    
    sns.swarmplot(
        x=feature_1, 
        y=feature_2, 
        hue='Survived', 
        data=df
    ).set_title(title)

# %% [markdown]
# ### Feature: Sex

# %%
# Make Plots
count_plot_function_categorical(train,"Sex", "Survived", "Sex vs Survival")
bar_plot_function_categorical(train,"Sex", "Survived", "Sex vs Survival")
bar_plot_function_categorical(train,"Pclass", "Survived", "Sex Pclass vs Survival", "Sex")
bar_plot_function_categorical(train,"Relatives", "Survived", "Sex Relative vs Survival", "Sex")
bar_plot_function_categorical(train,"Fare_Bins", "Survived", "Sex Fare_Bins vs Survival", "Sex")
bar_plot_function_categorical(train,"Age_Bins", "Survived", "Sex Age_Bins vs Survival", "Sex")

# %% [markdown]
# ### Feature: Pclass

# %%
count_plot_function_categorical(train,"Pclass", "Survived", "Pclass vs Survival")
bar_plot_function_categorical(train,"Pclass", "Survived", "Pclass vs Survival")
bar_plot_function_categorical(train,"Relatives", "Survived", "Pclass Relative vs Survival", "Pclass")
bar_plot_function_categorical(train,"Embarked", "Survived", "Pclass Relative vs Survival", "Pclass")
bar_plot_function_categorical(train,"Fare_Bins", "Survived", "Pclass Fare_Bins vs Survival", "Pclass", True)
bar_plot_function_categorical(train,"Age_Bins", "Survived", "Pclass Age_Bins vs Survival", "Pclass", True)
# Out:
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# ...

# %% [markdown]
# ### Feature: Name

# %% [markdown]
# ### Grouping Title

# %%
new_title = {
    'Mr' : 'Mr','Ms' : 'Ms','Mrs' : 'Mrs','Rev' : 'officer','Sir' : 'royalty','theCountess' : 'royalty','Dona' : 'royalty', 'Capt' : 'officer','Col' : 'officer','Don' : 'royalty','Dr' : 'officer','Jonkheer' : 'royalty','Lady' : 'royalty','Major' : 'officer','Master' : 'kid','Miss' : 'Ms','Mlle' : 'Ms','Mme' : 'Mrs'
}

#Add Title
def add_title(df):
    df['title'] = df['Name'].apply(lambda x: x.split(",")[1])
    df['title'] = df['title'].apply(lambda x: x.split(".")[0])
    df.title = df.title.str.replace(' ', '')

# %% [markdown]
# ### Extract Title

# %%
add_title(train)
display(pd.DataFrame(train.groupby('title')['PassengerId'].nunique().reset_index()))

# Group Titles
train['title'] = train['title'].apply(lambda x: new_title[x])
display(pd.DataFrame(train.groupby('title')['PassengerId'].nunique()))
# Out:
#           title  PassengerId
# 0          Capt            1
# 1           Col            2
# 2           Don            1
# 3            Dr            7
# 4      Jonkheer            1
# 5          Lady            1
# 6         Major            2
# 7        Master           40
# 8          Miss          182
# 9          Mlle            2
# 10          Mme            1
# 11           Mr          517
# 12          Mrs          125
# 13           Ms            1
# 14          Rev            6
# 15          Sir            1
# 16  theCountess            1
#          PassengerId
# title
# Mr               517
# Mrs              126
# Ms               185
# kid               40
# officer           18
# royalty            5

# %%
#Plots
count_plot_function_categorical(train,"title", "Survived", "Title vs Survival")
bar_plot_function_categorical(train,"title", "Survived", "Title vs Survival")
bar_plot_function_categorical(train,"Sex", "Survived", "Title Sex vs Survival", "title")
bar_plot_function_categorical(train,"Fare_Bins", "Survived", "Title Fare_Bins vs Survival", "title", True)
bar_plot_function_categorical(train,"Age_Bins", "Survived", "Title Age_Bins vs Survival", "title", True)
# Out:
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# ...

# %% [markdown]
# ### Feature: Age

# %%
train.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'Relatives',
#        'Fare_Bins', 'Age_Bins', 'title'],
#       dtype='object')

# %%
#Plots
count_plot_function_categorical(train,"Age_Bins", "Survived", "Age_Bins vs Survival", True)
bar_plot_function_categorical(train,"Age_Bins", "Survived", "Age_Bins vs Survival", None, True)

# %%
dist_plot(train, "Age", "Age Distribution")
dist_plot_survive(train, "Age", "Age Distribution with Survival")
swarm_plot(train, "Age", "Sex", "Age + Sex Vs Survival")
swarm_plot(train, "Pclass", "Age", "Age + Pclass Vs Survival")
# Out:
# C:\Users\Aman\.conda\envs\tf2\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ### Feature: Fare

# %%
#Plots
count_plot_function_categorical(train,"Fare_Bins", "Survived", "Fare_Bins vs Survival", True)
bar_plot_function_categorical(train,"Fare_Bins", "Survived", "Fare_Bins vs Survival", None, True)
dist_plot(train, "Fare", "Fare Distribution")
dist_plot_survive(train, "Fare", "Fare Distribution with Survival")
swarm_plot(train, "Fare", "Sex", "Fare + Sex Vs Survival")
swarm_plot(train, "Pclass", "Fare", "Fare + Pclass Vs Survival")
bar_plot_function_categorical(train,"Fare_Bins", "Survived", "Fare_Bins vs Survival", "Sex", True)
bar_plot_function_categorical(train,"Fare_Bins", "Survived", "Fare_Bins vs Survival", "Pclass", True)
# Out:
# C:\Users\Aman\.conda\envs\tf2\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Aman\.conda\envs\tf2\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 32.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Aman\.conda\envs\tf2\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 19.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %% [markdown]
# ### Feature: Cabin

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Relatives  \
# 0      0         A/5 21171   7.2500   NaN        S          1
# 1      0          PC 17599  71.2833   C85        C          1
# 2      0  STON/O2. 3101282   7.9250   NaN        S          0
# 3      0            113803  53.1000  C123        S          1
# ...

# %%
# Combining T with X due to similar behaviour
train["Cabin"] = train["Cabin"].apply(lambda x: "X" if pd.isnull(x) or x == "T" else x)
train["Cabin_Section"] = train['Cabin'].str[0]
display(pd.DataFrame(train.groupby('Cabin_Section')['PassengerId'].nunique()))
# Out:
#                PassengerId
# Cabin_Section
# A                       15
# B                       47
# C                       59
# D                       33
# E                       32
# F                       13
# G                        4
# X                      688

# %%
#Plots
count_plot_function_categorical(train,"Cabin_Section", "Survived", "Cabin_Section vs Survival")
bar_plot_function_categorical(train,"Cabin_Section", "Survived", "Cabin_Section vs Survival")
bar_plot_function_categorical(train,"Sex", "Survived", "Cabin_Section Sex vs Survival", "Cabin_Section")
bar_plot_function_categorical(train,"Pclass", "Survived", "Cabin_Section Pclass vs Survival", "Cabin_Section")
swarm_plot(train, "Cabin_Section", "Fare", "Cabin_Section + Fare Vs Survival")
# Out:
# C:\Users\Aman\.conda\envs\tf2\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 69.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# ...

# %% [markdown]
# ### Feature Relatives

# %%
count_plot_function_categorical(train,"Relatives", "Survived", "Fare vs Survival")
bar_plot_function_categorical(train,"Relatives", "Survived", "Fare vs Survival")
bar_plot_function_categorical(train,"Sex", "Survived", "Fare Sex vs Survival", "Relatives")
bar_plot_function_categorical(train,"Pclass", "Survived", "Fare Pclass vs Survival", "Relatives")
swarm_plot(train, "Relatives", "Fare", "Relatives + Fare Vs Survival")
swarm_plot(train, "Relatives", "Age", "Relatives + Age Vs Survival")
# Out:
# C:\Users\Aman\.conda\envs\tf2\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 70.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Aman\.conda\envs\tf2\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 9.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Aman\.conda\envs\tf2\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 5.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# ...
